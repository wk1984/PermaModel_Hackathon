# %% [markdown]
# ###### load Ku component from pymt

# %%
import matplotlib.pyplot as plt
import numpy as np
from permamodel.components import bmi_Ku_component

mod = bmi_Ku_component.BmiKuMethod()
cfg_dir = 'examples'

# %%
cfg_file = cfg_dir+'/'+'Ku_method_2D.cfg'
#%cat $cfg_file

# %% [markdown]
# ##### initialize ku model

# %%
mod.initialize(cfg_file)
mod.update()
mod.get_input_var_names()
# Out:
#
# Ku model component: Initializing...
# ('latitude',
#  'longitude',
#  'datetime__start',
#  'datetime__end',
#  'atmosphere_bottom_air__temperature',
#  'atmosphere_bottom_air__temperature_amplitude',
#  'snowpack__depth',
#  'snowpack__density',
#  'water-liquid__volumetric-water-content-soil',
#  'vegetation__Hvgf',
#  'vegetation__Hvgt',
#  'vegetation__Dvf',
#  'vegetation__Dvt')

# %%
mod.get_current_time()
# Out:
# 1.0

# %%
mod.update()
print(mod.get_current_time())
# Out:
# 2.0

# %%
ttop = mod.get_value('soil__temperature')

plt.figure(figsize=[11,2])

plt.imshow(ttop,vmin=-15, vmax=5)
plt.colorbar()

# %%
lat = mod.get_value('latitude')
lon = mod.get_value('longitude')

# %%
alt = mod.get_value('soil__active_layer_thickness')

plt.figure(figsize=[11,2])

plt.imshow(alt,vmin=0, vmax=2)
plt.colorbar()
